# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集
mnist = input_data.read_data_sets('MNIST_data',one_hot=True)

# 每个批次的大小
batch_size = 100
# 一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

# 定义两个变量
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])
keep_prob = tf.placeholder(tf.float32)

# 第一层隐藏层,激活函数为tanh,然后使用Dropout
W1 = tf.Variable(tf.truncated_normal([784,2000],stddev=0.1))
b1 = tf.Variable(tf.zeros([2000])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1,keep_prob)

# 第二层
W2 = tf.Variable(tf.truncated_normal([2000,2000],stddev=0.1))
b2 = tf.Variable(tf.zeros([2000])+0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2,keep_prob)

# 第三层
W3 = tf.Variable(tf.truncated_normal([2000,2000],stddev=0.1))
b3 = tf.Variable(tf.zeros([2000])+0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
L3_drop = tf.nn.dropout(L3,keep_prob)

# 输出层,激活函数使用softmax
W4 = tf.Variable(tf.truncated_normal([2000,10],stddev=0.1))
b4 = tf.Variable(tf.zeros([10])+0.1)
prediction = tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)

# 二次代价函数
# loss = tf.reduce_mean(tf.square(y-prediction))
# 交叉熵
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
train_step = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

# 结果存放
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))
# 准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

# 初始化
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
#     for _ in range(200):
#         print(sess.run([w,b]))
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys,keep_prob:0.7})
        
        train_acc = sess.run(accuracy,feed_dict={x:mnist.train.images,y:mnist.train.labels,keep_prob:1.0})
        test_acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
        print("Iter" + str(epoch) + ",Testing Accuracy " + str(test_acc) +",Traing Accuracy " + str(train_acc))

# %%
# keep_prob = 1.0
Iter0,Testing Accuracy 0.7629,Traing Accuracy 0.7662909
Iter1,Testing Accuracy 0.8613,Traing Accuracy 0.86563635
Iter2,Testing Accuracy 0.873,Traing Accuracy 0.88127273
Iter3,Testing Accuracy 0.871,Traing Accuracy 0.8843455
Iter4,Testing Accuracy 0.8766,Traing Accuracy 0.8876909
Iter5,Testing Accuracy 0.8782,Traing Accuracy 0.89076364
Iter6,Testing Accuracy 0.8769,Traing Accuracy 0.89025456
Iter7,Testing Accuracy 0.8832,Traing Accuracy 0.8959818
Iter8,Testing Accuracy 0.8826,Traing Accuracy 0.89689094
Iter9,Testing Accuracy 0.8837,Traing Accuracy 0.8974364
Iter10,Testing Accuracy 0.8845,Traing Accuracy 0.89772725
Iter11,Testing Accuracy 0.8839,Traing Accuracy 0.8980182
Iter12,Testing Accuracy 0.8844,Traing Accuracy 0.8983273
Iter13,Testing Accuracy 0.8842,Traing Accuracy 0.8986727
Iter14,Testing Accuracy 0.8845,Traing Accuracy 0.89885455
Iter15,Testing Accuracy 0.8852,Traing Accuracy 0.89894545
Iter16,Testing Accuracy 0.885,Traing Accuracy 0.89903635
Iter17,Testing Accuracy 0.9686,Traing Accuracy 0.9891273
Iter18,Testing Accuracy 0.9701,Traing Accuracy 0.9919818
Iter19,Testing Accuracy 0.9762,Traing Accuracy 0.9952545
Iter20,Testing Accuracy 0.9764,Traing Accuracy 0.9962364
