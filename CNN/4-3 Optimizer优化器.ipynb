# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集
mnist = input_data.read_data_sets('MNIST_data',one_hot=True)

# 每个批次的大小
batch_size = 100
# 一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

# 定义两个变量
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])

# 创建一个简单的神经网络
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W)+b)

# 二次代价函数
# loss = tf.reduce_mean(tf.square(y-prediction))
# 交叉熵
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
# train_step = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
# train_step = tf.train.AdamOptimizer(1e-2).minimize(loss)
train_step = tf.train.AdadeltaOptimizer(0.5).minimize(loss)

# 结果存放
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))
# 准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

# 初始化
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
#     for _ in range(200):
#         print(sess.run([w,b]))
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter" + str(epoch) + ",Testing Accuracy " + str(acc))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter0,Testing Accuracy 0.8242
# Iter1,Testing Accuracy 0.882
# Iter2,Testing Accuracy 0.891
# Iter3,Testing Accuracy 0.8972
# Iter4,Testing Accuracy 0.9026
# Iter5,Testing Accuracy 0.9042
# Iter6,Testing Accuracy 0.907
# Iter7,Testing Accuracy 0.9082
# Iter8,Testing Accuracy 0.9098
# Iter9,Testing Accuracy 0.9117
# Iter10,Testing Accuracy 0.9118
# Iter11,Testing Accuracy 0.9122
# Iter12,Testing Accuracy 0.914
# Iter13,Testing Accuracy 0.9145
# Iter14,Testing Accuracy 0.9154
# Iter15,Testing Accuracy 0.9168
# Iter16,Testing Accuracy 0.9172
# Iter17,Testing Accuracy 0.9177
# Iter18,Testing Accuracy 0.9182
# Iter19,Testing Accuracy 0.9188
# Iter20,Testing Accuracy 0.9189

# %%
# 梯度下降法
Iter0,Testing Accuracy 0.8971
Iter1,Testing Accuracy 0.9084
Iter2,Testing Accuracy 0.9129
Iter3,Testing Accuracy 0.9157
Iter4,Testing Accuracy 0.9177
Iter5,Testing Accuracy 0.9196
Iter6,Testing Accuracy 0.919
Iter7,Testing Accuracy 0.9214
Iter8,Testing Accuracy 0.9222
Iter9,Testing Accuracy 0.9229
Iter10,Testing Accuracy 0.9226
Iter11,Testing Accuracy 0.9229
Iter12,Testing Accuracy 0.9234
Iter13,Testing Accuracy 0.9237
Iter14,Testing Accuracy 0.925
Iter15,Testing Accuracy 0.9256
Iter16,Testing Accuracy 0.9251
Iter17,Testing Accuracy 0.9253
Iter18,Testing Accuracy 0.9243
Iter19,Testing Accuracy 0.9256
Iter20,Testing Accuracy 0.9269

# Adam优化器
Iter0,Testing Accuracy 0.9234
Iter1,Testing Accuracy 0.9257
Iter2,Testing Accuracy 0.9282
Iter3,Testing Accuracy 0.9304
Iter4,Testing Accuracy 0.9302
Iter5,Testing Accuracy 0.928
Iter6,Testing Accuracy 0.9308
Iter7,Testing Accuracy 0.9248
Iter8,Testing Accuracy 0.9298
Iter9,Testing Accuracy 0.9294
Iter10,Testing Accuracy 0.9324
Iter11,Testing Accuracy 0.9334
Iter12,Testing Accuracy 0.9302
Iter13,Testing Accuracy 0.9325
Iter14,Testing Accuracy 0.9322
Iter15,Testing Accuracy 0.9332
Iter16,Testing Accuracy 0.9304
Iter17,Testing Accuracy 0.9301
Iter18,Testing Accuracy 0.93
Iter19,Testing Accuracy 0.9302
Iter20,Testing Accuracy 0.9295

# Adadelta优化器
Iter0,Testing Accuracy 0.8242
Iter1,Testing Accuracy 0.882
Iter2,Testing Accuracy 0.891
Iter3,Testing Accuracy 0.8972
Iter4,Testing Accuracy 0.9026
Iter5,Testing Accuracy 0.9042
Iter6,Testing Accuracy 0.907
Iter7,Testing Accuracy 0.9082
Iter8,Testing Accuracy 0.9098
Iter9,Testing Accuracy 0.9117
Iter10,Testing Accuracy 0.9118
Iter11,Testing Accuracy 0.9122
Iter12,Testing Accuracy 0.914
Iter13,Testing Accuracy 0.9145
Iter14,Testing Accuracy 0.9154
Iter15,Testing Accuracy 0.9168
Iter16,Testing Accuracy 0.9172
Iter17,Testing Accuracy 0.9177
Iter18,Testing Accuracy 0.9182
Iter19,Testing Accuracy 0.9188
Iter20,Testing Accuracy 0.9189
