# %% [markdown]
# # 个人简历
#
#
#
# ### 联系方式
#
#  * 手机 : 18758288579
#  * Email : Lebhoryi@gmail.com
#  * QQ/微信 : 1281327753
#  * Github : https://github.com/Michael1S
#
#
# ###  个人信息
#
#  * 陈晨毅/男/1994
#  * 本科/台州学院/电气工程及其自动化
#  * 硕士/浙江工商大学/电子与通信工程
#  * 工作年限 : 一年
#  * Github : https://github.com/Michael1S
#  * 期望城市 : 杭州
#
# ----
#
# ### 在校项目
#
#  1. (开源)[私有云笔记] (https://github.com/hkurj/SelfNote): 使用
#    Python,Django,Bootstrap,Js,Html,Mysql建立的web端私有云笔记,负责Django的后台搭建以及API各接口调试
#  2. 使用CNN提高MNIST手写数字识别的准确率
#     * [源码] (https://github.com/Michael1S/tf_201806/tree/master/CNN)
#  * 使用RNN提高MNIST手写数字识别的准确率
#     * [源码] (https://github.com/Michael1S/tf_201806/tree/master/RNN)
#  * 尝试AlexNet网络
#     * 使用MNIST数据集
#     * 整个网络模型重新训练参数
#     * 代码执行的时候Jupyter抛出'Kernel Died'，暂无修正
#     * [源码] (https://github.com/Michael1S/tf_201806/tree/master/AlexNet_%E5%A4%8D%E7%8E%B0)
#  * 使用Inception网络实现图片分类
#     * [图片数据集] (http://www.robots.ox.ac.uk/~vgg/data/)
#     * [Inception_v3模型] (http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz)
#     * 两种方法:
#        1.只更改最后一层，softmax，进行训练
#        2.从头开始训练一个模型，进行训练
#     * [源码] (https://github.com/Michael1S/tf_201806/tree/master/Inception%E5%AE%9E%E7%8E%B0%E5%9B%BE%E7%89%87%E5%88%86%E7%B1%BB)
#
# ---
#
# ### 证书
#
#  * 浙江省电子竞赛二等奖(二等奖第二名)
#  * CET-4
#  * 浙江省二级计算机
#  * 高级电工证
#  * C1驾照
#
# ### 技能清单
#
#  * 熟练:
#     * 语言 : Python,C，shell
#     * 操作系统 : Linux
#     * 框架 : Tensorflow
#     * 网络 : CNN,RNN,AlexNet
#
#  * 了解:
#     * 语言 : Html,C++
#     * 代码托管 : Git
#     * 数据库 : Mysql
#     * 框架 : Django
#     * 网络 : LeNet-5,VGG16,Inception,GoogLeNet,ResNet
#     * 算法 : Logistic Regression,SVM,决策树,BP算法，贝叶斯分类器，聚类
#     * 其他 : 梯度下降法,交叉熵，L2正则，过拟合
#
# ---
#
# ### 成长经历
#
#  * 大一入学第二天加入了电子科技协会，开始学习51单片机
#  * 大一下学期帮助学长经营淘宝店,并且借了定制的单子,独立完成了制作
#  * 大二暑假休学一年，于宁波从事房地产相关工作
#  * 大三复学，参加浙江省电子设计竞赛，获二等奖
#  * 大四顺利考研
#  * 大四喜欢上了Python 这门语言所以就自学了Python,Django以及爬虫入
#  * 研一开始学习嵌入式系统,接触了Linux操作系统
#  * 研一下在导师的引导下开始学习深度学习,主要是学习网易云课堂上的**吴恩达**老师的深度学习微专业
#
# ### 其他
#
#  * 兴趣爱好 : 健身,跑步(参加过杭马),羽毛球
#  * 自我评价 :
#     1.执行力 > 责任心 > 任务
#     2.擅外交
#     3.常自省
#
# ---
#
# ** 感谢您花时间阅读我的简历,期待能有机会和您共事。 **

# %% [markdown]
#     在jupyter上画不出分隔线，
#     Markdown语法的分隔线是：
#
# > --- or === or ***
#
#     但是在Jupyter上就是不显示，使用这个[网址](http://mahua.jser.me/)进行转化
#
# ___

# %% [markdown]
# <table><tr><td bgcolor=orange> 背景色是：orange </td></tr></table>
# ___
#
# <hr />

# %% [markdown]
# <h1>This is header 1</h1>
# <hr>
# <p>This is some text</p>
